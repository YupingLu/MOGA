# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import math

# %%
def extract(fname):
    df = pd.read_csv(fname, header=None)
    data = df.to_numpy()
    da_t = data[:,15:17]
    da = np.mean(da_t, axis=1).reshape(-1, 1)
    ma = data[:,17].reshape(-1, 1)
    em = data[:,2].reshape(-1, 1)
    dm = np.hstack((da, ma, em))
    return dm

# %%
def extract1(fname):
    df = pd.read_csv(fname, header=None)
    data1 = df.to_numpy()
    data = data1[data1[:,-2] == 1]
    da_t = data[:,15:17]
    da = np.mean(da_t, axis=1).reshape(-1, 1)
    ma = data[:,17].reshape(-1, 1)
    em = data[:,2].reshape(-1, 1)
    dm = np.hstack((da, ma, em))
    return dm

# %%
def ds3(df):
    l = len(df)
    eps0 = 90
    da0 = -60000
    ma0 = -0.03
    delta = 0

    for idx in range(0, l, 1):
      delta += ((df[idx, 2] - eps0) / eps0) ** 2 + ((df[idx, 0] - da0) / da0) ** 2 + ((df[idx, 1] - ma0) / ma0) ** 2

    delta = math.sqrt(delta) / l
    return delta

# %%
a = []
x = list(range(1, 9, 1))

x1 = ds3(extract('/data/ylu/11knobs/res/ml/1.1_ml/gen_732_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/track/1.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
a.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/ml/2.1_ml/gen_900_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/track/2.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
a.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/ml/3.1_ml/gen_600_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/track/3.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
a.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/ml/4_ml/gen_1200_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/track/4.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
a.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/ml/5_ml/gen_900_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/track/5.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
a.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/ml/6_ml/gen_400_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/track/6.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
a.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/ml/7_ml/gen_700_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/track/7.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
a.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/ml/8_ml/gen_1000_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/track/8.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
a.append(x2 - x1)
# Out:
# 0.0173
# 0.0836
#
#
# 0.0179
# 0.0805
#
#
# 0.0178
# 0.0712
#
#
# 0.0175
# 0.0583
#
#
# 0.0169
# 0.0577
#
#
# 0.0168
# 0.0490
#
#
# 0.0167
# 0.0477
#
#
# 0.0166
# 0.0444

# %%
b = []
w = list(range(1, 7, 1))

x1 = ds3(extract('/data/ylu/11knobs/res/rd_ml/rd_1.1_ml/gen_1100_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/rd_track/rd_1.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
b.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/rd_ml/rd_2.1_ml/gen_1200_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/rd_track/rd_2.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
b.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/rd_ml/rd_3_ml/gen_600_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/rd_track/rd_3.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
b.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/rd_ml/rd_4_ml/gen_1300_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/rd_track/rd_4.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
b.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/rd_ml/rd_5_ml/gen_900_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/rd_track/rd_5.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
b.append(x2 - x1)

x1 = ds3(extract('/data/ylu/11knobs/res/rd_ml/rd_6_ml/gen_1150_db.dat'))
x2 = ds3(extract1('/data/ylu/11knobs/res/rd_track/rd_6.1_track/gen_1_db.dat'))
print("{:.4f}".format(x1))
print("{:.4f}".format(x2))
print("\n")
b.append(x2 - x1)
# Out:
# 0.0174
# 0.1098
#
#
# 0.0166
# 0.0757
#
#
# 0.0164
# 0.0676
#
#
# 0.0167
# 0.0542
#
#
# 0.0166
# 0.0507
#
#
# 0.0165
# 0.0491

# %%
MEDIUM_SIZE = 20
#plt.rc('font', size=MEDIUM_SIZE) 
plt.rc('axes', titlesize=MEDIUM_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=MEDIUM_SIZE)    # legend fontsize

plt.figure(figsize=(12,9))
plt.plot(x, a, color='b', marker=".", linestyle='dashed', markersize=30, alpha=0.75, label='ML-MOGA 1')
plt.plot(w, b, color='r', marker=".", linestyle='dashed', markersize=30, alpha=0.75, label='ML-MOGA 2')

plt.xlabel('No. of ML-MOGA Iterations')
plt.ylabel('Shift of Distance Metric $\Delta_f$ [ ]')
plt.tick_params(axis='both', direction='out', grid_color='gray', grid_alpha=0.5)
plt.legend()

plt.tight_layout()
plt.savefig('fig_convergence_mlmoga_iterations.pdf')
